# %%
import os

# %%
root_path = r"D:\Users\hkolb\Documents\PythonProjects\sharepoint_data_crawler\data\ONEDRIVE_1_19-11-2025"

# %%
for path, dir, files in os.walk(root_path):
    if "reporting" in path.lower():
        if "docx" in ", ".join(files):
            print(path[len(root_path)+1:path.rfind("\\")].upper())
            for file in files:
                if "docx" in file:
                    print(f"Reporting/{file}")
            print()
# Out:
# 1007 - LION PICTURES FRAMING SUPPLIES LIMITED
# Reporting/Lion Pictures Framing Supplies Limited Memo Report.docx
#
# 1011 - MANTZARIS
# Reporting/Case Summary Condensed - Slug.docx
#
# 1033 - ISLAND EXCURSIONS, SL
# Reporting/Rapid Response Summary - ISLAND EXCURSIONS, S.L.  - SC - v0.1.docx
# Reporting/Rapid Response Summary - ISLAND EXCURSIONS, S.L.  - SC - v0.2.docx
# Reporting/Rapid Response Summary - ISLAND EXCURSIONS, S.L.  - SC - v0.3 -DW review.docx

# %%
import sys
sys._getframe(1).f_lineno
# Out:
# 3577
