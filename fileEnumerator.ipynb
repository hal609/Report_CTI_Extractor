# %%
import os

# %%
root_path = r"D:\Users\hkolb\Downloads\OneDrive_1_19-11-2025"

# %%
for path, dir, files in os.walk(root_path):
    if "reporting" in path.lower():
        if "docx" in ", ".join(files):
            print(path[54:path.rfind("\\")].upper())
            for file in files:
                if "docx" in file:
                    print(f"Reporting/{file}")
            print()
# Out:
# LION PICTURES FRAMING SUPPLIES LIMITED
# Reporting/Lion Pictures Framing Supplies Limited Memo Report.docx
#
# MANTZARIS
# Reporting/Case Summary Condensed - Slug.docx
#
# ISLAND EXCURSIONS, SL
# Reporting/Rapid Response Summary - ISLAND EXCURSIONS, S.L.  - SC - v0.1.docx
# Reporting/Rapid Response Summary - ISLAND EXCURSIONS, S.L.  - SC - v0.2.docx
# Reporting/Rapid Response Summary - ISLAND EXCURSIONS, S.L.  - SC - v0.3 -DW review.docx

# %%
# %reload_ext autoreload
# %autoreload 2

from docx_extractor import get_tabular_data

get_tabular_data(r"D:\Users\hkolb\Documents\PythonProjects\sharepoint_data_crawler\docx_extraction\Rapid Response Summary.docx")
# Out:
#                                                    0  \
# 0                                    Name of insured
# 1                      Date of incident notification
# 0      Type of incident Remove all that do NOT apply
# 1  Incident location Use  ISO TWO-letter country ...
# 2  Industry of insured Use  single  letter  indus...
# 3  Did the insured retain KPMG for post-incident ...
#
#                            1
# 0                    Sonepar
# 1            2 7 / 01 /202 5
# 0  Hacking  (False Positive)
# 1       France (HQ) & Norway
# 2                          J
# 3                         NO
